# %%
import pandas as pd

# %%
props = pd.read_csv("http://www.firstpythonnotebook.org/_static/committees.csv")

# %%
props.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 1  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 2  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 3  ocd-contest/b51dc64d-3562-4913-a190-69f5088c22a6            1376258
# 4  ocd-contest/85990193-9d6f-4600-b8e7-bf1317841d82            1362198
#
#    ccdc_prop_id                                          prop_name  \
# 0            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 1            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 2            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 3            70  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...
# 4            71  PROPOSITION 052 - STATE FEES ON HOSPITALS. FED...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                382                 1374469
# ...

# %%
props.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 8 columns):
# ocd_prop_id               102 non-null object
# calaccess_prop_id         102 non-null int64
# ccdc_prop_id              102 non-null int64
# prop_name                 102 non-null object
# ccdc_committee_id         102 non-null int64
# calaccess_committee_id    102 non-null int64
# committee_name            102 non-null object
# committee_position        102 non-null object
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB

# %%
contribs = pd.read_csv("http://www.firstpythonnotebook.org/_static/contributions.csv")

# %%
contribs.head()
# Out:
#    calaccess_committee_id                              committee_name  \
# 0                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 1                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 2                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 3                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
# 4                 1386560  ADULT USE CAMPAIGN FOR PROPOSITION 64; THE
#
#    calaccess_filing_id date_received contributor_lastname  \
# 0              2083796    2016-09-18              BERGMAN
# 1              2083796    2016-09-18                KAHLE
# 2              2083796    2016-07-15             MCDEVITT
# 3              2083796    2016-08-10      WARREN-SAMARIPA
# 4              2083796    2016-07-26      WARREN-SAMARIPA
#
#   contributor_firstname contributor_city contributor_state contributor_zip  \
# 0              GRETCHEN    SPRING VALLEY                CA           91978
# ...

# %%
contribs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56379 entries, 0 to 56378
# Data columns (total 13 columns):
# calaccess_committee_id          56379 non-null int64
# committee_name                  56379 non-null object
# calaccess_filing_id             56379 non-null int64
# date_received                   56379 non-null object
# contributor_lastname            56375 non-null object
# contributor_firstname           53411 non-null object
# contributor_city                56369 non-null object
# contributor_state               56363 non-null object
# contributor_zip                 56366 non-null object
# contributor_employer            48572 non-null object
# contributor_occupation          53273 non-null object
# contributor_is_self_employed    56379 non-null bool
# amount                          56379 non-null float64
# dtypes: bool(1), float64(1), int64(2), object(9)
# memory usage: 5.2+ MB

# %%
props.prop_name.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 9   PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 10  PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 11  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 12  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# ...

# %%
contribs.amount.max()
# Out:
# 12500000.0

# %%
contribs.amount.min()
# Out:
# -150000.0

# %%
contribs.amount.rank()
# Out:
# 0        12280.5
# 1         7258.0
# 2        21990.5
# 3           47.5
# 4         9480.5
# 5        21990.5
# 6        16339.5
# 7         7035.0
# 8        12280.5
# 9        12280.5
# 10        7532.0
# 11       21232.5
# 12       52417.5
# 13       54903.5
# 14       54903.5
# 15       12280.5
# 16        9480.5
# 17       52243.0
# 18       23015.5
# 19       52243.0
# 20       54368.5
# 21       53720.5
# 22       23015.5
# 23       23015.5
# 24       53225.0
# 25       52417.5
# 26       55307.0
# 27       55668.0
# 28       55307.0
# 29       55337.5
#           ...
# 56349    16339.5
# 56350    16339.5
# 56351    16339.5
# 56352    16339.5
# 56353    16339.5
# 56354    16339.5
# 56355    16339.5
# 56356    16339.5
# 56357    16339.5
# 56358    16339.5
# 56359    16339.5
# 56360    16339.5
# 56361    16339.5
# 56362    16339.5
# 56363    16339.5
# 56364    16339.5
# 56365        2.0
# 56366        4.0
# 56367    56115.0
# 56368    56115.0
# 56369    56115.0
# ...

# %%
contribs.amount.mean()
# Out:
# 7254.135574238634

# %%
contribs.amount.median()
# Out:
# 287.08

# %%
contribs.amount.info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-7380f9d50daa> in <module>()
# ----> 1 contribs.amount.info()
#
# /Users/mdevries/Dropbox/Study/Python/Code/mbp-python-notebook/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'info'

# %%
contribs.amount.pd.stats()

# %%
contribs.amount.sum()
# Out:
# 408980909.53999996

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
props.prop_name.value_counts().reset_index()
# Out:
#                                                 index  prop_name
# 0   PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE...         13
# 1   PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...         12
# 2   PROPOSITION 064- MARIJUANA LEGALIZATION. INITI...         11
# 3   PROPOSITION 066- DEATH PENALTY. PROCEDURES. IN...          9
# 4   PROPOSITION 055 - TAX EXTENSION TO FUND EDUCAT...          8
# 5   PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON...          7
# 6   PROPOSITION 062- DEATH PENALTY. INITIATIVE STA...          7
# 7   PROPOSITION 059- SB 254 (CHAPTER 20, STATUTES ...          6
# 8   PROPOSITION 053 - REVENUE BONDS. STATEWIDE VOT...          4
# 9   PROPOSITION 054 - LEGISLATURE. LEGISLATION AND...          4
# 10  PROPOSITION 058 - SB 1174 (CHAPTER 753, STATUT...          4
# 11  PROPOSITION 063- FIREARMS. AMMUNITION SALES. I...          4
# 12  PROPOSITION 051 - SCHOOL BONDS. FUNDING FOR K-...          4
# ...

# %%
props.prop_name.value_counts()
# Out:
# PROPOSITION 057 - CRIMINAL SENTENCES. JUVENILE CRIMINAL PROCEEDINGS AND SENTENCING. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.                           13
# PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE.    12
# PROPOSITION 064- MARIJUANA LEGALIZATION. INITIATIVE STATUTE.                                                                                                   11
# PROPOSITION 066- DEATH PENALTY. PROCEDURES. INITIATIVE STATUTE.                                                                                                 9
# PROPOSITION 055 - TAX EXTENSION TO FUND EDUCATION AND HEALTHCARE. INITIATIVE CONSTITUTIONAL AMENDMENT.                                                          8
# PROPOSITION 067- REFERENDUM TO OVERTURN BAN ON SINGLE-USE PLASTIC BAGS.                                                                                         7
# ...

# %%
gun_prop = props[props.prop_name == "PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTHCARE, TOBACCO USE PREVENTION, RESEARCH, AND LAW ENFORCEMENT. INITIATIVE CONSTITUTIONAL AMENDMENT AND STATUTE."]

# %%
gun_prop.head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 23  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 24  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 25  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 26  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 27  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
#
#     ccdc_prop_id                                          prop_name  \
# 23            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 24            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 25            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 26            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 27            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 23                405                 1388865
# ...

# %%
gun_prop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 23 to 34
# Data columns (total 8 columns):
# ocd_prop_id               12 non-null object
# calaccess_prop_id         12 non-null int64
# ccdc_prop_id              12 non-null int64
# prop_name                 12 non-null object
# ccdc_committee_id         12 non-null int64
# calaccess_committee_id    12 non-null int64
# committee_name            12 non-null object
# committee_position        12 non-null object
# dtypes: int64(4), object(4)
# memory usage: 864.0+ bytes

# %%
merged = pd.merge(gun_prop, contribs, on = "calaccess_committee_id")

# %%
merged.head()
# Out:
#                                         ocd_prop_id  calaccess_prop_id  \
# 0  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 1  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 2  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 3  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 4  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
#
#    ccdc_prop_id                                          prop_name  \
# 0            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 1            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 2            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 3            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 4            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
#
#    ccdc_committee_id  calaccess_committee_id  \
# 0                405                 1388865
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 165 entries, 0 to 164
# Data columns (total 20 columns):
# ocd_prop_id                     165 non-null object
# calaccess_prop_id               165 non-null int64
# ccdc_prop_id                    165 non-null int64
# prop_name                       165 non-null object
# ccdc_committee_id               165 non-null int64
# calaccess_committee_id          165 non-null int64
# committee_name_x                165 non-null object
# committee_position              165 non-null object
# committee_name_y                165 non-null object
# calaccess_filing_id             165 non-null int64
# date_received                   165 non-null object
# contributor_lastname            165 non-null object
# contributor_firstname           65 non-null object
# contributor_city                165 non-null object
# contributor_state               165 non-null object
# contributor_zip                 165 non-null object
# ...

# %%
merged.amount.sum()
# Out:
# 88369291.670000002

# %%
merged.committee_position.value_counts()
# Out:
# SUPPORT    119
# OPPOSE      46
# Name: committee_position, dtype: int64

# %%
support = merged[merged.committee_position == "SUPPORT"]

# %%
oppose = merged[merged.committee_position == "OPPOSE"]

# %%
oppose.amount.sum()
# Out:
# 54686004.0

# %%
support.amount.sum()
# Out:
# 33683287.670000002

# %%
oppose.amount.sum()/support.amount.sum()
# Out:
# 1.6235352242265251

# %%
merged.sort_values("amount", ascending = False)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 29   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 36   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 83   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 24   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 30   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 37   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 25   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 119  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 74   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 103  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 102  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 138  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# ...

# %%
oppose.sort_values("amount", ascending=False)
# Out:
#                                           ocd_prop_id  calaccess_prop_id  \
# 29   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 36   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 24   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 30   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 37   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 25   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 31   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 38   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 33   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 26   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 32   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 27   ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# ...

# %%
oppose.sort_values("amount", ascending = False).head()
# Out:
#                                          ocd_prop_id  calaccess_prop_id  \
# 29  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 36  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 24  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 30  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
# 37  ocd-contest/c2efe0d3-e9f4-4dfd-a0b7-a35757ef4ae9            1381640
#
#     ccdc_prop_id                                          prop_name  \
# 29            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 36            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 24            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 30            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
# 37            75  PROPOSITION 056 - CIGARETTE TAX TO FUND HEALTH...
#
#     ccdc_committee_id  calaccess_committee_id  \
# 29                407                 1386637
# ...

# %%
merged.groupby("committee_name_x").amount.sum().reset_index().sort_values("amount", ascending = False)
# Out:
#                                      committee_name_x       amount
# 6   NO ON 56 - STOP THE SPECIAL INTEREST TAX GRAB....  54650500.00
# 9   YES ON 56 - SAVES LIVES CALIFORNIA, A COALITIO...  29267861.00
# 5   MILLION VOTER PROJECT ACTION FUND - YES ON 55,...   2110000.00
# 3   FIGHT CANCER - YES ON 56, SPONSORED BY AMERICA...    801450.00
# 4   MILLION VOTER PROJECT ACTION FUND - YES ON 55 ...    426035.55
# 1   CALIFORNIA KIDS CAMPAIGN, YES ON PROPS 55 & 56...    295000.00
# 2   COMMON SENSE KIDS ACTION, INC., YES ON PROPS. ...    295000.00
# 10  YES ON 56 STOP CANCER - PLANNED PARENTHOOD ADV...    250000.00
# 11  YES ON 56 STOP CANCER - PLANNED PARENTHOOD OF ...    200000.00
# 7   PICO CALIFORNIA - YES ON 55, 56, AND 57 (NON P...     37941.12
# 0   CALIFORNIA CITIZENS AGAINST SPECIAL INTERESTS ...     32050.00
# 8   PROTECT SMALL BUSINESS AND SMOKE FREE ALTERNAT...      3454.00

# %%
merged.groupby(["contributor_lastname","committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False)
# Out:
#                                   contributor_lastname committee_position  \
# 82   PHILIP MORRIS USA INC. (MADE BY ITS SERVICE CO...             OPPOSE
# 98   R.J. REYNOLDS TOBACCO COMPANY (MADE BY ITS SER...             OPPOSE
# 110                                             STEYER            SUPPORT
# 13   CA HOSPITALS COMMITTEE ON ISSUES, (CHCI) SPONS...            SUPPORT
# 120  UST LLC (MADE BY ITS SERVICE COMPANY, ALTRIA C...             OPPOSE
# 20   CALIFORNIA STATE COUNCIL OF SERVICE EMPLOYEES ...            SUPPORT
# 49                                      ITG BRANDS LLC             OPPOSE
# 54   JOHN MIDDLETON CO. (MADE BY ITS SERVICE COMPAN...             OPPOSE
# 55   KAISER FOUNDATION HEALTH PLAN, INC. AND THE HO...            SUPPORT
# 18                      CALIFORNIA MEDICAL ASSOCIATION            SUPPORT
# 17   CALIFORNIA HOSPITALS COMMITTEE ON ISSUES, (CHC...            SUPPORT
# 16                       CALIFORNIA DENTAL ASSOCIATION            SUPPORT
# ...

# %%
contribs[contribs.contributor_state != "CA"].amount.sum() / contribs.amount.sum()
# Out:
# 0.35727983265612256

# %%
contribs.count()
# Out:
# calaccess_committee_id          56379
# committee_name                  56379
# calaccess_filing_id             56379
# date_received                   56379
# contributor_lastname            56375
# contributor_firstname           53411
# contributor_city                56369
# contributor_state               56363
# contributor_zip                 56366
# contributor_employer            48572
# contributor_occupation          53273
# contributor_is_self_employed    56379
# amount                          56379
# dtype: int64

# %%
contribs.amount.count()
# Out:
# 56379

# %%
numerator = contribs[contribs.contributor_state != "CA"].amount.count()

# %%
denominator = contribs.amount.count()

# %%
numerator / denominator
# Out:
# 0

# %%
numerator
# Out:
# 2542

# %%
denominator
# Out:
# 56379

# %%
2542/56379
# Out:
# 0

# %%
from __future__ import division

# %%
2542/56379
# Out:
# 0.04508770996292946

# %%
contribs[contribs.contributor_state != "CA"].amount.count() / contribs.amount.count()
# Out:
# 0.045087709962929462

# %%
merged.groupby(["contributor_employer", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False).head(20)
# Out:
#                       contributor_employer committee_position      amount
# 17                         NEXTGEN CLIMATE            SUPPORT  11300000.0
# 12                        FARALLON CAPITAL            SUPPORT   1750000.0
# 6                             BLOOMBERG LP            SUPPORT    500000.0
# 1                       AKONADI FOUNDATION            SUPPORT     75000.0
# 4                       ARTICLE 3 ADVISORS            SUPPORT     50000.0
# 14                 KAITLYN TRIGGER KRIEGER            SUPPORT     25000.0
# 0                             ADAM GUNTHER            SUPPORT     10000.0
# 18                                    NONE            SUPPORT      2512.0
# 27            TELFORD'S PIPE & CIGAR, INC.             OPPOSE      1000.0
# 29   UNIVERSITY OF CALIFORNIA, LOS ANGELES            SUPPORT       500.0
# 5                           BAIN & COMPANY            SUPPORT       500.0
# 26                     STANFORD UNIVERSITY            SUPPORT       350.0
# ...

# %%
merged.groupby("committee_name_x").amount.count().reset_index().sort_values("amount")
# Out:
#                                      committee_name_x  amount
# 10  YES ON 56 STOP CANCER - PLANNED PARENTHOOD ADV...       1
# 11  YES ON 56 STOP CANCER - PLANNED PARENTHOOD OF ...       1
# 1   CALIFORNIA KIDS CAMPAIGN, YES ON PROPS 55 & 56...       2
# 2   COMMON SENSE KIDS ACTION, INC., YES ON PROPS. ...       2
# 7   PICO CALIFORNIA - YES ON 55, 56, AND 57 (NON P...       2
# 5   MILLION VOTER PROJECT ACTION FUND - YES ON 55,...       6
# 8   PROTECT SMALL BUSINESS AND SMOKE FREE ALTERNAT...       8
# 4   MILLION VOTER PROJECT ACTION FUND - YES ON 55 ...      10
# 3   FIGHT CANCER - YES ON 56, SPONSORED BY AMERICA...      14
# 0   CALIFORNIA CITIZENS AGAINST SPECIAL INTERESTS ...      18
# 6   NO ON 56 - STOP THE SPECIAL INTEREST TAX GRAB....      20
# 9   YES ON 56 - SAVES LIVES CALIFORNIA, A COALITIO...      81

# %%
def combine_names(row):
    if row.is_org:
        return row.contributor_lastname
    return row.contributor_fullname

# %%
merged['contributor_fullname'] = merged.contributor_firstname + " " + merged.contributor_lastname

# %%
merged['is_org'] = merged.contributor_firstname.isnull()

# %%
merged['contributor_cleanname'] = merged.apply(combine_names, axis = 1)

# %%
merged.groupby(["contributor_cleanname", "committee_position"]).amount.sum().reset_index().sort_values("amount", ascending=False).head(20)
# Out:
#                                  contributor_cleanname committee_position  \
# 82   PHILIP MORRIS USA INC. (MADE BY ITS SERVICE CO...             OPPOSE
# 97   R.J. REYNOLDS TOBACCO COMPANY (MADE BY ITS SER...             OPPOSE
# 115                                   THOMAS F. STEYER            SUPPORT
# 16   CA HOSPITALS COMMITTEE ON ISSUES, (CHCI) SPONS...            SUPPORT
# 121  UST LLC (MADE BY ITS SERVICE COMPANY, ALTRIA C...             OPPOSE
# 24   CALIFORNIA STATE COUNCIL OF SERVICE EMPLOYEES ...            SUPPORT
# 116                                      THOMAS STEYER            SUPPORT
# 48                                      ITG BRANDS LLC             OPPOSE
# 51   JOHN MIDDLETON CO. (MADE BY ITS SERVICE COMPAN...             OPPOSE
# 20                       CALIFORNIA DENTAL ASSOCIATION            SUPPORT
# 22                      CALIFORNIA MEDICAL ASSOCIATION            SUPPORT
# 21   CALIFORNIA HOSPITALS COMMITTEE ON ISSUES, (CHC...            SUPPORT
# ...
